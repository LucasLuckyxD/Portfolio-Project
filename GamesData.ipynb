# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasLuckyxD/Portfolio-Project/blob/main/GamesData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Importing Libraries***

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ***Reading The Dataset***

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset Pandas/Game Sales Data/dato.csv')
df
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41,36    28,96     3,77
# 1         Wii    Racing              Nintendo    15,68     12,8     3,79
# 2         Wii    Sports              Nintendo    15,61    10,95     3,28
# 3          DS  Platform              Nintendo    11,28     9,15      6,5
# 4         Wii      Misc              Nintendo    13,96     9,18     2,93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %% [markdown]
# ***Replacing the ',' into '.' for mathematical Calculation***

# %%
df.dtypes
# Out:
# Platform              object
# Genre                 object
# Publisher             object
# NA_Sales              object
# EU_Sales              object
# JP_Sales              object
# Other_Sales           object
# Global_Sales          object
# Rating                object
# Critic_Score_Class    object
# dtype: object

# %%
df= df.applymap(lambda x:x.replace(',','.'))

# %%
df
# Out:
#      Platform     Genre             Publisher NA_Sales EU_Sales JP_Sales  \
# 0         Wii    Sports              Nintendo    41.36    28.96     3.77
# 1         Wii    Racing              Nintendo    15.68     12.8     3.79
# 2         Wii    Sports              Nintendo    15.61    10.95     3.28
# 3          DS  Platform              Nintendo    11.28     9.15      6.5
# 4         Wii      Misc              Nintendo    13.96     9.18     2.93
# ...       ...       ...                   ...      ...      ...      ...
# 7107       PC    Action               Ubisoft        0        0        0
# 7108       PC   Shooter          Midway Games        0        0        0
# 7109       PC    Sports                  Sega        0        0        0
# 7110       PC  Strategy  Take-Two Interactive        0        0        0
# 7111      PS4  Platform             Team Meat        0        0        0
#
#      Other_Sales Global_Sales Rating Critic_Score_Class
# ...

# %%
df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']] = df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].astype(float)

# %%
df
# Out:
#      Platform     Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Wii    Sports              Nintendo     41.36     28.96      3.77
# 1         Wii    Racing              Nintendo     15.68     12.80      3.79
# 2         Wii    Sports              Nintendo     15.61     10.95      3.28
# 3          DS  Platform              Nintendo     11.28      9.15      6.50
# 4         Wii      Misc              Nintendo     13.96      9.18      2.93
# ...       ...       ...                   ...       ...       ...       ...
# 7107       PC    Action               Ubisoft      0.00      0.00      0.00
# 7108       PC   Shooter          Midway Games      0.00      0.00      0.00
# 7109       PC    Sports                  Sega      0.00      0.00      0.00
# 7110       PC  Strategy  Take-Two Interactive      0.00      0.00      0.00
# 7111      PS4  Platform             Team Meat      0.00      0.00      0.00
#
# ...

# %% [markdown]
# ***Ubisoft rating and Critic Score Class on PC with the Shooter Genre***

# %%
group1 = df.groupby(['Publisher','Platform','Genre'])

# %%
asdf = group1[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum().reset_index()

# %%
Ubisoft_Group = group1.get_group(('Ubisoft','PC','Shooter'))

# %%
df_for_plot = pd.DataFrame()
df_for_plot = Ubisoft_Group.copy()
df_for_plot
# Out:
#      Platform    Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 1386       PC  Shooter   Ubisoft      0.22      0.63       0.0         0.12
# 1983       PC  Shooter   Ubisoft      0.16      0.45       0.0         0.05
# 2800       PC  Shooter   Ubisoft      0.23      0.16       0.0         0.04
# 3859       PC  Shooter   Ubisoft      0.14      0.08       0.0         0.02
# 4553       PC  Shooter   Ubisoft      0.05      0.10       0.0         0.02
# 5216       PC  Shooter   Ubisoft      0.05      0.05       0.0         0.01
# 6305       PC  Shooter   Ubisoft      0.00      0.04       0.0         0.01
# 6556       PC  Shooter   Ubisoft      0.00      0.03       0.0         0.00
# 6724       PC  Shooter   Ubisoft      0.00      0.02       0.0         0.00
# 6728       PC  Shooter   Ubisoft      0.00      0.02       0.0         0.00
# 6918       PC  Shooter   Ubisoft      0.00      0.01       0.0         0.00
# ...
